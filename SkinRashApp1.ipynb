# %%
# !pip install -Uqq fastbook
# !pip install graphviz
# Out:
# ERROR: voila 0.2.6 has requirement nbconvert<7,>=6.0.0, but you'll have nbconvert 5.6.1 which is incompatible.
# Requirement already satisfied: graphviz in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.16)

# %%
import fastbook
fastbook.setup_book()
from fastbook import *
from fastai.vision.widgets import *
from ipywidgets import *
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl',cpu=True)

# %%
btn_upload = widgets.FileUpload()

# %%
btn_run = widgets.Button(description='Classify')
lbl_pred = widgets.Label()

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
out_pl = widgets.Output()
out_pl.clear_output()

# %%
display(VBox([widgets.Label('Select your rash!'), 
      btn_upload, btn_run, out_pl, lbl_pred]))
# Out:
# VBox(children=(Label(value='Select your rash!'), FileUpload(value={}, description='Upload'), Button(descriptio…

# %%
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila
# Out:
# Requirement already satisfied: voila in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.2.6)
# Requirement already satisfied: jupyter-client<7,>=6.1.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from voila) (6.1.6)
# Collecting nbconvert<7,>=6.0.0
#   Using cached nbconvert-6.0.7-py3-none-any.whl (552 kB)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from voila) (0.5.1)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from voila) (1.2.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client<7,>=6.1.3->voila) (4.6.3)
# Requirement already satisfied: traitlets in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client<7,>=6.1.3->voila) (4.3.3)
# Requirement already satisfied: pyzmq>=13 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client<7,>=6.1.3->voila) (19.0.1)
# Requirement already satisfied: python-dateutil>=2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client<7,>=6.1.3->voila) (2.8.1)
# Requirement already satisfied: tornado>=4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-client<7,>=6.1.3->voila) (6.1)
# Requirement already satisfied: testpath in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.4.4)
# Requirement already satisfied: nbformat>=4.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (5.0.7)
# Requirement already satisfied: jupyterlab-pygments in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.8.4)
# Requirement already satisfied: pygments>=2.4.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (2.6.1)
# Requirement already satisfied: bleach in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (3.1.5)
# Requirement already satisfied: entrypoints>=0.2.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.3)
# Requirement already satisfied: defusedxml in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (0.6.0)
# Requirement already satisfied: jinja2>=2.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbconvert<7,>=6.0.0->voila) (2.11.2)
# Requirement already satisfied: nest-asyncio in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.4.3)
# Requirement already satisfied: async-generator in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbclient<0.6,>=0.4.0->voila) (1.10)
# Requirement already satisfied: prometheus-client in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.8.0)
# Requirement already satisfied: Send2Trash in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (1.5.0)
# Requirement already satisfied: anyio>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (2.0.2)
# Requirement already satisfied: terminado>=0.8.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.8.3)
# Requirement already satisfied: ipython-genutils in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila) (0.2.0)
# Requirement already satisfied: six in /srv/conda/envs/notebook/lib/python3.7/site-packages (from traitlets->jupyter-client<7,>=6.1.3->voila) (1.15.0)
# Requirement already satisfied: decorator in /srv/conda/envs/notebook/lib/python3.7/site-packages (from traitlets->jupyter-client<7,>=6.1.3->voila) (4.4.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (3.2.0)
# Requirement already satisfied: packaging in /srv/conda/envs/notebook/lib/python3.7/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (20.4)
# Requirement already satisfied: webencodings in /srv/conda/envs/notebook/lib/python3.7/site-packages (from bleach->nbconvert<7,>=6.0.0->voila) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert<7,>=6.0.0->voila) (1.1.1)
# Requirement already satisfied: sniffio>=1.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from anyio>=2.0.2->jupyter-server<2.0.0,>=0.3.0->voila) (1.2.0)
# Requirement already satisfied: idna>=2.8 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from anyio>=2.0.2->jupyter-server<2.0.0,>=0.3.0->voila) (2.10)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from anyio>=2.0.2->jupyter-server<2.0.0,>=0.3.0->voila) (3.7.4.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (0.16.0)
# Requirement already satisfied: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (49.2.0.post20200712)
# Requirement already satisfied: attrs>=17.4.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (19.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /srv/conda/envs/notebook/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (1.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from packaging->bleach->nbconvert<7,>=6.0.0->voila) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.4->nbconvert<7,>=6.0.0->voila) (3.1.0)
# ERROR: nbdev 1.1.6 has requirement nbconvert<6, but you'll have nbconvert 6.0.7 which is incompatible.
# Installing collected packages: nbconvert
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 5.6.1
#     Uninstalling nbconvert-5.6.1:
#       Successfully uninstalled nbconvert-5.6.1
# Successfully installed nbconvert-6.0.7
# Enabling: voila
# - Writing config: /srv/conda/envs/notebook/etc/jupyter
#     - Validating...
#       voila 0.2.6 OK
